# %%
import os
os.chdir('/media/star3/vinu/maps/bruteforce')

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import mpld3

# %%
mpld3.enable_notebook()

# %%
import cc_at_physical_scale as cc

# %%
reload(cc)
Nprocess = 10
NperProcess = 20

types = ['bd']

params = cc.get_params()
pid = params[0] 
mtype = params[2]
d_bins = params[3]

o_nside = params[1] # 1 for 857 and 8 for rest
# Out:
# R_bins  =  [  0.     0.25   0.5    0.75   1.     2.     4.     7.    10.    20.    30.
#   50.  ]
# RvUnit  =  False
# compute_Rv  =  True
# d_bins  =  [  0.     0.25   0.5    0.75   1.     1.5    2.     3.     4.     5.     6.
#    7.    10.    15.    20.    30.    40.    50.  ]
# ignore_z_high  =  0.3
# ignore_z_low  =  0.01
# jack_percent  =  0.3
# ksigma  =  1000000000.0
# mtype  =  1
# o_nside  =  8
# remove_857  =  True
# remove_obj_radec  =  True
# remove_random  =  mj_rcorr
# struct  =  c

# %% [markdown]
# ## Running correlation function on random B' map

# %%
random = 4
struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mbins[0][0], mbins[0][1], mtype, o_nside, types[0], random)

cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)
# Out:
# theta max 29.00
# nside, d_max, zl_min, zl_max
#  2 50.0 0.0238553 0.116547
# #  20
# theta max 6.05
# nside, d_max, zl_min, zl_max
#  8 50.0 0.11681 0.136638
# #  20
# theta max 5.19
# nside, d_max, zl_min, zl_max
#  16 50.0 0.136988 0.151968
# #  20
# theta max 4.66
# nside, d_max, zl_min, zl_max
#  16 50.0 0.152934 0.161408
# #  20
# theta max 4.43
# nside, d_max, zl_min, zl_max
#  16 50.0 0.161494 0.166408
# #  20
# theta max 4.30
# nside, d_max, zl_min, zl_max
#  16 50.0 0.166495 0.170116
# #  20
# theta max 4.21
# nside, d_max, zl_min, zl_max
#  16 50.0 0.170142 0.173825
# #  20
# theta max 4.11
# nside, d_max, zl_min, zl_max
#  16 50.0 0.174462 0.178521
# #  20
# theta max 4.01
# nside, d_max, zl_min, zl_max
#  16 50.0 0.179127 0.182031
# #  20
# theta max 3.95
# nside, d_max, zl_min, zl_max
#  16 50.0 0.182096 0.184953
# #  20
# theta max 3.89
# nside, d_max, zl_min, zl_max
#  16 50.0 0.184996 0.189061
# #  20
# theta max 3.80
# nside, d_max, zl_min, zl_max
# ...

# %%
random = 5
struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mbins[0][0], mbins[0][1], mtype, o_nside, types[0], random)

cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)
# Out:
# theta max 29.00
# nside, d_max, zl_min, zl_max
#  2 50.0 0.0238553 0.116547
# #  20
# theta max 6.05
# nside, d_max, zl_min, zl_max
#  8 50.0 0.11681 0.136638
# #  20
# theta max 5.19
# nside, d_max, zl_min, zl_max
#  16 50.0 0.136988 0.151968
# #  20
# theta max 4.66
# nside, d_max, zl_min, zl_max
#  16 50.0 0.152934 0.161408
# #  20
# theta max 4.43
# nside, d_max, zl_min, zl_max
#  16 50.0 0.161494 0.166408
# #  20
# theta max 4.30
# nside, d_max, zl_min, zl_max
#  16 50.0 0.166495 0.170116
# #  20
# theta max 4.21
# nside, d_max, zl_min, zl_max
#  16 50.0 0.170142 0.173825
# #  20
# theta max 4.11
# nside, d_max, zl_min, zl_max
#  16 50.0 0.174462 0.178521
# #  20
# theta max 4.01
# nside, d_max, zl_min, zl_max
#  16 50.0 0.179127 0.182031
# #  20
# theta max 3.95
# nside, d_max, zl_min, zl_max
#  16 50.0 0.182096 0.184953
# #  20
# theta max 3.89
# nside, d_max, zl_min, zl_max
#  16 50.0 0.184996 0.189061
# #  20
# theta max 3.80
# nside, d_max, zl_min, zl_max
# ...

# %%
random = 6
struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mbins[0][0], mbins[0][1], mtype, o_nside, types[0], random)

cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)
# Out:
# theta max 29.00
# nside, d_max, zl_min, zl_max
#  2 50.0 0.0238553 0.116547
# #  20
# theta max 6.05
# nside, d_max, zl_min, zl_max
#  8 50.0 0.11681 0.136638
# #  20
# theta max 5.19
# nside, d_max, zl_min, zl_max
#  16 50.0 0.136988 0.151968
# #  20
# theta max 4.66
# nside, d_max, zl_min, zl_max
#  16 50.0 0.152934 0.161408
# #  20
# theta max 4.43
# nside, d_max, zl_min, zl_max
#  16 50.0 0.161494 0.166408
# #  20
# theta max 4.30
# nside, d_max, zl_min, zl_max
#  16 50.0 0.166495 0.170116
# #  20
# theta max 4.21
# nside, d_max, zl_min, zl_max
#  16 50.0 0.170142 0.173825
# #  20
# theta max 4.11
# nside, d_max, zl_min, zl_max
#  16 50.0 0.174462 0.178521
# #  20
# theta max 4.01
# nside, d_max, zl_min, zl_max
#  16 50.0 0.179127 0.182031
# #  20
# theta max 3.95
# nside, d_max, zl_min, zl_max
#  16 50.0 0.182096 0.184953
# #  20
# theta max 3.89
# nside, d_max, zl_min, zl_max
#  16 50.0 0.184996 0.189061
# #  20
# theta max 3.80
# nside, d_max, zl_min, zl_max
# ...

# %% [markdown]
# ## Generating random y-map (randomizing y-map)

# %%
sys.path.append('../')
import helper_funcs as hf

# %%
hf.randomize_ymap('../ludo1_ra_dec_y_2048_noavg_nside8_bd.fits', '../random_nside8_bd_9.fits')

# %%
hf.randomize_ymap('../ludo1_ra_dec_y_2048_noavg_nside8_ed.fits', '../random_nside8_ed_9.fits')

# %% [markdown]
# ## Running correlation function on random B' map

# %%
Nprocess = 30
NperProcess = 500

types = ['bd']
mbins = zip([14], [14.5])
for random in range(6, 10):
    struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mbins[0][0], mbins[0][1], mtype, o_nside, types[0], random)

    cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)
# Out:
# theta max 31.55
# nside, d_max, zl_min, zl_max
#  2 50.0 0.021915 0.135807
# #  500
# theta max 5.23
# nside, d_max, zl_min, zl_max
#  16 50.0 0.135902 0.165493
# #  500
# theta max 4.32
# nside, d_max, zl_min, zl_max
#  16 50.0 0.165503 0.184409
# #  500
# theta max 3.90
# nside, d_max, zl_min, zl_max
#  16 50.0 0.184451 0.197008
# #  500
# theta max 3.66
# nside, d_max, zl_min, zl_max

# %%
Nprocess = 30
NperProcess = 500

types = ['bd']
mbins = zip([13], [14])
for random in range(6, 10):
    struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mbins[0][0], mbins[0][1], mtype, o_nside, types[0], random)

    cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)

# %%
Nprocess = 30
NperProcess = 500

types = ['bd']
mbins = zip([12], [13])
for random in range(6, 10):
    struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mbins[0][0], mbins[0][1], mtype, o_nside, types[0], random)

    cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)

# %%
Nprocess = 30
NperProcess = 500

types = ['bd']
mbins = zip([11], [12])
for random in range(6, 10):
    struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mbins[0][0], mbins[0][1], mtype, o_nside, types[0], random)

    cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)

# %% [markdown]
# ## Running correlation function on random E' map

# %%
Nprocess = 30
NperProcess = 500

types = ['ed']
mbins = zip([14], [14.5])
for random in range(6, 10):
    struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mbins[0][0], mbins[0][1], mtype, o_nside, types[0], random)

    cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)

# %%
Nprocess = 30
NperProcess = 500

types = ['ed']
mbins = zip([13], [14])
for random in range(6, 10):
    struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mbins[0][0], mbins[0][1], mtype, o_nside, types[0], random)

    cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)

# %%
Nprocess = 30
NperProcess = 500

types = ['ed']
mbins = zip([12], [13])
for random in range(6, 10):
    struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mbins[0][0], mbins[0][1], mtype, o_nside, types[0], random)

    cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)

# %%
Nprocess = 30
NperProcess = 500

types = ['ed']
mbins = zip([11], [12])
for random in range(6, 10):
    struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mbins[0][0], mbins[0][1], mtype, o_nside, types[0], random)

    cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)

# %%
pl.hist(np.random.randint(0, 10, 100))
# Out:
# (array([ 11.,  14.,  10.,  13.,  11.,  10.,  12.,   4.,   8.,   7.]),
#  array([ 0. ,  0.9,  1.8,  2.7,  3.6,  4.5,  5.4,  6.3,  7.2,  8.1,  9. ]),
#  <a list of 10 Patch objects>)

# %%
Nprocess = 30
NperProcess = 500

types = ['ed']
mbins = zip([13], [14])
random = 1
struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mbins[0][0], mbins[0][1], mtype, o_nside, types[0], random)
cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)

# %%
Nprocess = 30
NperProcess = 500

types = ['ed']
mbins = zip([12], [13])
random = 1
struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mbins[0][0], mbins[0][1], mtype, o_nside, types[0], random)
cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)

# %%
Nprocess = 30
NperProcess = 500

types = ['ed']
mbins = zip([11], [12])
random = 1
struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mbins[0][0], mbins[0][1], mtype, o_nside, types[0], random)
cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)

# %%
Nprocess = 30
NperProcess = 500

types = ['bd']
mbins = zip([13], [14])
random = 1
struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mbins[0][0], mbins[0][1], mtype, o_nside, types[0], random)
cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)

# %%
Nprocess = 30
NperProcess = 500

types = ['bd']
mbins = zip([12], [13])
random = 1
struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mbins[0][0], mbins[0][1], mtype, o_nside, types[0], random)
cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)

# %%
Nprocess = 30
NperProcess = 500

types = ['bd']
mbins = zip([11], [12])
random = 1
struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mbins[0][0], mbins[0][1], mtype, o_nside, types[0], random)
cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)

# %%
Nprocess = 30
NperProcess = 500

types = ['bd']
mbins = zip([11, 12, 13, 14, 14.5], [12, 13, 14, 14.5, 16])
for mmin, mmax in mbins:
    struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mmin, mmax, mtype, o_nside, types[0], 0)

    cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)

# %%
Nprocess = 30
NperProcess = 500

types = ['ed']
mbins = zip([11, 12, 13, 14, 14.5], [12, 13, 14, 14.5, 16])
for mmin, mmax in mbins:
    struc_cata, y_cata, ofile, back_857 = cc.get_filenames(mmin, mmax, mtype, o_nside, types[0], 0)

    cc.run_cc(struc_cata, y_cata, ofile, d_bins, pid, Nprocess, NperProcess)

# %%
import power_spectrum_analysis_857 as ps

# %% [markdown]
# # ZodiCorrected

# %%
ps.power_spectra_857('bd')
# Out:
# NSIDE = 2048
# ORDERING = RING in fits file
# NSIDE = 2048
# ORDERING = RING in fits file
# NSIDE = 2048
# ORDERING = RING in fits file
# NSIDE = 2048
# ORDERING = RING in fits file
# <power_spectrum_analysis_857.power_spectra_857 instance at 0x5ad8440>

# %%
ps.fitting('bd')
# Out:
# [  3.61070054e-06   3.69294027e-06]
# [[  1.61783847e-07   1.60346996e-07]
#  [  1.60346996e-07   1.73134037e-07]]
# Chi2 = 88.67
# (array([  3.61070054e-06,   3.69294027e-06]),
#  array([[  2.61740133e-14,   2.57111591e-14],
#         [  2.57111591e-14,   2.99753947e-14]]),
#  array([  8.78609174e-09,   5.51669334e-09,   3.50480581e-09,
#           2.45741380e-09,   1.75796023e-09,   1.36352488e-09,
#           1.03199278e-09,   8.20941878e-10,   6.17764387e-10,
#           4.56317108e-10,   3.48182219e-10,   2.49380552e-10,
#           2.09441555e-10,   1.80286567e-10,   1.74556454e-10,
#           1.96038849e-10]),
#  array([  7.81300295e-09,   5.60074707e-09,   4.36585450e-09,
#           3.11683529e-09,   1.89985106e-09,   1.58078060e-09,
#           1.41122627e-09,   7.25919577e-10,   3.88857381e-10,
#           2.24251546e-10,   2.35013656e-10,   3.32337347e-10,
#           8.11025975e-11,   2.41480466e-10,   2.98132417e-10,
#           8.13772064e-11]),
# ...

# %%
ps.power_spectra_857('ed')
# Out:
# NSIDE = 2048
# ORDERING = RING in fits file
# NSIDE = 2048
# ORDERING = RING in fits file
# NSIDE = 2048
# ORDERING = RING in fits file
# NSIDE = 2048
# ORDERING = RING in fits file
# <power_spectrum_analysis_857.power_spectra_857 instance at 0x5aa8cf8>

# %%
ps.fitting('ed')
# Out:
# [  1.83768020e-06   1.86373502e-06]
# [[  5.06453267e-08   5.25438351e-08]
#  [  5.25438351e-08   5.47183949e-08]]
# Chi2 = 564.21
# (array([  1.83768020e-06,   1.86373502e-06]),
#  array([[  2.56494912e-15,   2.76085460e-15],
#         [  2.76085460e-15,   2.99410274e-15]]),
#  array([  4.43784840e-09,   2.78972774e-09,   1.77594559e-09,
#           1.24847264e-09,   8.96636645e-10,   6.98847412e-10,
#           5.32527852e-10,   4.27139698e-10,   3.25768028e-10,
#           2.45663759e-10,   1.92216749e-10,   1.43969522e-10,
#           1.24821640e-10,   1.11677179e-10,   1.10289840e-10,
#           1.21968261e-10]),
#  array([  3.69246979e-09,   2.61970517e-09,   1.87706242e-09,
#           1.41381475e-09,   1.01862904e-09,   7.49795490e-10,
#           5.31950514e-10,   4.07538208e-10,   3.01783331e-10,
#           2.24478914e-10,   1.80283311e-10,   1.39197977e-10,
#           1.27903625e-10,   1.14632127e-10,   1.15389832e-10,
#           1.25979110e-10]),
# ...

# %% [markdown]
# # Zod Uncorrected

# %%
reload(ps)
ps.power_spectra_857('bd')
# Out:
# NSIDE = 2048
# ORDERING = RING in fits file
# NSIDE = 2048
# ORDERING = RING in fits file
# NSIDE = 2048
# ORDERING = RING in fits file
# NSIDE = 2048
# ORDERING = RING in fits file
# <power_spectrum_analysis_857.power_spectra_857 instance at 0x7f4f107af3b0>

# %%
ps.fitting('bd')
# Out:
# [  2.59497476e-06   3.48425455e-06]
# [[  1.70361166e-07              nan]
#  [             nan   1.52389484e-07]]
# Chi2 = 81.25
# power_spectrum_analysis_857.py:144: RuntimeWarning: invalid value encountered in sqrt
#   pl.figure(3, figsize=(7,7))
# (array([  2.59497476e-06,   3.48425455e-06]),
#  array([[  2.90229269e-14,  -1.32155337e-15],
#         [ -1.32155337e-15,   2.32225549e-14]]),
#  array([  9.26013333e-09,   7.14375523e-09,   5.87409577e-09,
#           5.25007841e-09,   4.64380255e-09,   4.11466520e-09,
#           3.60678988e-09,   3.27119109e-09,   2.87002257e-09,
#           2.51612837e-09,   2.18524094e-09,   1.91277032e-09,
#           1.69638954e-09,   1.43899257e-09,   1.26500633e-09,
#           1.13990753e-09]),
#  array([  8.37583703e-09,   6.91120973e-09,   6.43222263e-09,
#           5.34097752e-09,   5.01419797e-09,   4.82313526e-09,
#           5.21253695e-09,   3.39678295e-09,   2.38478138e-09,
# ...

# %%
ps.power_spectra_857('ed')
# Out:
# NSIDE = 2048
# ORDERING = RING in fits file
# NSIDE = 2048
# ORDERING = RING in fits file
# NSIDE = 2048
# ORDERING = RING in fits file
# NSIDE = 2048
# ORDERING = RING in fits file
# <power_spectrum_analysis_857.power_spectra_857 instance at 0x5b2e290>

# %%
ps.fitting('ed')
# Out:
# [  1.14035149e-06   1.64391139e-06]
# [[  7.58417377e-09   9.60681469e-09]
#  [  9.60681469e-09   1.57613981e-08]]
# Chi2 = 171.54
# (array([  1.14035149e-06,   1.64391139e-06]),
#  array([[  5.75196918e-17,   9.22908886e-17],
#         [  9.22908886e-17,   2.48421671e-16]]),
#  array([  4.34877855e-09,   3.34011756e-09,   2.73255687e-09,
#           2.43205116e-09,   2.13969281e-09,   1.88312225e-09,
#           1.63808397e-09,   1.47363435e-09,   1.27801459e-09,
#           1.10357300e-09,   9.41335416e-10,   8.03998301e-10,
#           6.96425797e-10,   5.66451644e-10,   4.76184064e-10,
#           4.12612011e-10]),
#  array([  3.95700808e-09,   3.17008360e-09,   2.68163791e-09,
#           2.44224331e-09,   2.18112718e-09,   1.94141851e-09,
#           1.67449789e-09,   1.50033687e-09,   1.30176070e-09,
#           1.10140539e-09,   9.30247611e-10,   7.88555298e-10,
#           6.74025650e-10,   5.63526027e-10,   4.88999926e-10,
#           4.12671078e-10]),
# ...
