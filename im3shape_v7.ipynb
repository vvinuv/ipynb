# %%
import os

# %%
os.chdir('/home/vinu/data/DES_vinu/DES_catalogs/')

# %%
from astropy.io import fits
import numpy as np
import pylab as pl
import basics as bas

# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import mpld3

# %%
mpld3.disable_notebook()

# %% [markdown]
# 1. For v6 I noticed that <e2> correlates with mask fraction (see figure in section 8). Some correlation still exists in v7 (see figure in section 3a)
# 2. I removed objects with larger mask fraction and estimated <e1> & <e2>. See section 3. For example with mask fraction < 0.3, <e2> changes from 1.05e-03 to 4.83e-04
#
# 3. Section 7 shows that there are some tiles with large average and error values on e1 and e2. Are those tiles are potentially problematic?

# %% [markdown]
# ## 1. im3shape v7

# %%
im3 = fits.open('/home/vinu/data/DES_vinu/DES_catalogs/v7/www.usm.uni-muenchen.de/~dgruen/des/im3shapev7/im3shape_r_v7_valid_spte_Sept18.fits')[1].data

# %%
print im3.names
# Out:
# ['COADD_OBJECTS_ID_1', 'ZP_gold', 'ZPE', 'RA', 'DEC', 'FLUX_RADIUS_R', 'E1', 'E2', 'im3shape_r_ra_as', 'im3shape_r_dec_as', 'im3shape_r_radius', 'snr', 'im3shape_r_likelihood', 'im3shape_r_bulge_flux', 'im3shape_r_disc_flux', 'im3shape_r_mean_flux', 'im3shape_r_n_exposure', 'im3shape_r_stamp_size', 'error_flag', 'info_flag', 'mean_psf_e1_sky', 'mean_psf_e2_sky', 'Tile', 'SPREAD_MODEL_R', 'SPREAD_MODEL_I', 'SPREADERR_MODEL_I', 'CLASS_STAR_I', 'MAG_AUTO_R', 'MAG_AUTO_I', 'ANNZ', 'ANNZ_err', 'MODEST_CLASS', 'crazy_color', 'radius', 'radius_ratio', 'bulge_A', 'disc_A', 'min_residuals', 'max_residuals', 'model_min', 'model_max', 'mask_fraction', 'covmat_2_2', 'covmat_2_3', 'covmat_3_2', 'covmat_3_3', 'mean_rgpp_rp', 'mean_psf_fwhm', 'chi2_pixel']

# %% [markdown]
# ## 2. Objects with ERROR/INFO FLAGS=0 and in SPT-E field

# %%
print im3.shape
e = (im3['error_flag'] == 0) &  (im3['info_flag'] == 0) & (im3['snr'] > 0) & (im3['modest_class']==1)
im3 = im3[e]
print im3.shape
# Out:
# (6546590,)
# (1869787,)

# %% [markdown]
# ## 3. Removing galaxies with larger mask fraction

# %%
im3_mf_0p4 = im3[(im3['mask_fraction'] < 0.4)]

# %%
print '# of objects: total = %d, mask fraction < 0.4 %d'%(im3.shape[0], im3_mf_0p4.shape[0])
print 'No mask fraction : %.2e %.2e'%(im3['im3shape_r_e1'].mean(), im3['im3shape_r_e2'].mean())
print 'Mask fraction < 0.4 :%.2e %.2e'%(im3_mf_0p4['im3shape_r_e1'].mean(), im3_mf_0p4['im3shape_r_e2'].mean())
# Out:
# # of objects: total = 1869787, mask fraction < 0.4 1709987
# No mask fraction : -9.39e-05 1.04e-03
# Mask fraction < 0.4 :-2.29e-04 7.80e-04

# %%
im3_mf_0p3 = im3[(im3['mask_fraction'] < 0.3)]

# %%
print '# of objects: total = %d, mask fraction < 0.3 %d'%(im3.shape[0], im3_mf_0p3.shape[0])
print 'No mask fraction : %.2e %.2e'%(im3['im3shape_r_e1'].mean(), im3['im3shape_r_e2'].mean())
print 'Mask fraction < 0.3 :%.2e %.2e'%(im3_mf_0p3['im3shape_r_e1'].mean(), im3_mf_0p3['im3shape_r_e2'].mean())
# Out:
# # of objects: total = 1869787, mask fraction < 0.3 1455221
# No mask fraction : -9.39e-05 1.04e-03
# Mask fraction < 0.3 :-5.26e-04 4.76e-04

# %%
im3_mf_0p2 = im3[(im3['mask_fraction'] < 0.2)]

# %%
print '# of objects: total = %d, mask fraction < 0.2 %d'%(im3.shape[0], im3_mf_0p2.shape[0])
print 'No mask fraction : %.2e %.2e'%(im3['im3shape_r_e1'].mean(), im3['im3shape_r_e2'].mean())
print 'Mask fraction < 0.2 :%.2e %.2e'%(im3_mf_0p2['im3shape_r_e1'].mean(), im3_mf_0p2['im3shape_r_e2'].mean())
# Out:
# # of objects: total = 1869787, mask fraction < 0.2 1072278
# No mask fraction : -9.39e-05 1.04e-03
# Mask fraction < 0.2 :-5.48e-04 -7.15e-05

# %%
im3_mf_0p1 = im3[(im3['mask_fraction'] < 0.1)]

# %% [markdown]
# ### 3a. Plotting $<e_1>$ and $<e_2>$ vs Mask fraction

# %%
bas.plot_maskfrac(im3['MASK_FRACTION'], im3['im3shape_r_e1'], im3['im3shape_r_e2'])

# %% [markdown]
# ### 3b. Plotting $<e1>$ and $<e2>$ of PSF vs Mask fraction

# %%
bas.plot_maskfrac(im3['MASK_FRACTION'], im3['im3shape_r_psf_e1_sky_mean'], im3['im3shape_r_psf_e2_sky_mean'])

# %% [markdown]
# ## 4. Plotting $<e_1>$ and $<e_2>$ vs radius

# %%
im3_rad_3p5 = im3[(im3['radius'] < 3.5)]

# %%
print '# of objects: total = %d, radius < %d'%(im3.shape[0], im3_rad_3p5.shape[0])
print 'No radius cut : %.2e %.2e'%(im3['im3shape_r_e1'].mean(), im3['im3shape_r_e2'].mean())
print 'Including radius cut < 3.5 arcsec :%.2e %.2e'%(im3_rad_3p5['im3shape_r_e1'].mean(), im3_rad_3p5['im3shape_r_e2'].mean())
# Out:
# # of objects: total = 1869787, radius < 1707481
# No radius cut : -9.39e-05 1.04e-03
# Including radius cut < 3.5 arcsec :-7.62e-04 6.61e-04

# %%
reload(bas)
bas.plot_rad(im3['radius'], im3['im3shape_r_e1'], im3['im3shape_r_e2'], 20, 30)
# Out:
# basics.py:9: RuntimeWarning: invalid value encountered in divide
#   return avg, std/np.sqrt(N)

# %% [markdown]
# ## 5. Plotting $<e_1>$ and $<e_2>$ vs RGPP_RP

# %%
reload(bas)
bas.plot_q(im3['mean_rgpp_rp'], im3['im3shape_r_e1'], im3['im3shape_r_e2'], 0, 3, 20, 'RGPP_RP', ylim=[-0.01, 0.01])

# %% [markdown]
# ## 6. Plotting $<e_1>$ and $<e_2>$ vs PSF FWHM

# %%
reload(bas)
bas.plot_q(im3['mean_psf_fwhm'], im3['im3shape_r_e1'], im3['im3shape_r_e2'], 3, 4.5, 20, 'FWHM')#, ylim=[-0.03, 0.03])

# %% [markdown]
# ## 7. Plotting quantities per tile

# %%
reload(bas)
bas.titles_avg(im3['tile'], im3['ra'], im3['dec'], im3['im3shape_r_e1'], im3['im3shape_r_e2'], 'tiles_all_v7.npz')

# %%
reload(bas)
p = bas.plot_tiles('tiles_all_v7.npz', histbin=30, histrange=[-0.02, 0.02], tile_ylim=[-0.02,0.02], estd=1)
# Out:
# Removing all tiles with error on <e1> and <e2> larger than 1.0e+00
# All tiles: <e1> = -7.5672e-05 <e2> = 1.2262e-03
# # of tiles included 288 out of 288
# Removed tiles <e1> = -7.5672e-05 <e2> = 1.2262e-03

# %%
reload(bas)
p = bas.plot_tiles('tiles_all_v7.npz', histbin=50, histrange=[-0.01, 0.01], tile_ylim=[-0.02,0.02], estd=0.005, Nremove=0)
# Out:
# Removing all tiles with error on <e1> and <e2> larger than 5.0e-03
# All tiles: <e1> = -7.5672e-05 <e2> = 1.2262e-03
# # of tiles included 228 out of 288
# Removed tiles <e1> = 1.9292e-05 <e2> = 6.6864e-04

# %%
reload(bas)
p = bas.plot_tiles('tiles_all_v7.npz', histbin=50, histrange=[-0.01, 0.01], tile_ylim=[-0.02,0.02], estd=0.0045, Nremove=0)
# Out:
# Removing all tiles with error on <e1> and <e2> larger than 4.5e-03
# All tiles: <e1> = -7.5672e-05 <e2> = 1.2262e-03
# # of tiles included 216 out of 288
# Removed tiles <e1> = 1.2100e-04 <e2> = 5.1727e-04

# %%
reload(bas)
p = bas.plot_tiles('tiles_all_v7.npz', histbin=50, histrange=[-0.01, 0.01], tile_ylim=[-0.02,0.02], estd=0.004, Nremove=0)
# Out:
# Removing all tiles with error on <e1> and <e2> larger than 4.0e-03
# All tiles: <e1> = -7.5672e-05 <e2> = 1.2262e-03
# # of tiles included 195 out of 288
# Removed tiles <e1> = 3.9484e-05 <e2> = 4.0304e-04

# %% [markdown]
# ## 8. Gal vs PSF as function of mask fraction

# %%
reload(bas)
for tim3, color, mf in zip([im3, im3_mf_0p4, im3_mf_0p3, im3_mf_0p2, im3_mf_0p1], ['r', 'g', 'b', 'k', 'm'], 
                              [0.5, 0.4, 0.3, 0.2, 0.1]):
   bas.plot_psf((tim3['mean_psf_e1_sky']), tim3['e1'], -0.01, 0.03, 10, 
                'MF=%.1f'%mf, color, 'E1', ylim=(-0.005, 0.005)) 
pl.savefig('PSF-E1.eps', bbox_inches='tight')

# %%
reload(bas)
for tim3, color, mf in zip([im3, im3_mf_0p4, im3_mf_0p3, im3_mf_0p2, im3_mf_0p1], ['r', 'g', 'b', 'k', 'm'], 
                              [0.5, 0.4, 0.3, 0.2, 0.1]):
    bas.plot_psf((tim3['mean_psf_e2_sky']), tim3['e2'], -0.01, 0.03, 10, 
                'MF=%.1f'%mf, color, 'E2', ylim=(-0.005, 0.009)) 
pl.savefig('PSF-E2.eps', bbox_inches='tight')

# %%
pl.hist(im3['mask_fraction'], 20)
pl.xlabel('Mask fraction')
pl.ylabel('Number')

# %%
pl.figure(figsize=(7,7))
xx = pl.hist(im3['im3shape_r_psf_e1_sky_mean'], 20, histtype='step', color='k')
xx = pl.hist(im3['im3shape_r_psf_e2_sky_mean'], 20, histtype='step', color='r')
pl.xlabel('PSF E')
pl.ylabel('Number')

# %%
psf_con = (abs(im3['im3shape_r_psf_e1_sky_mean']) <  0.02)
bas.plot_maskfrac(im3['MASK_FRACTION'][psf_con], im3['im3shape_r_e1'][psf_con], im3['im3shape_r_e2'][psf_con])

# %% [markdown]
# ## 9. Map of number of objects/galaxies/stars in gold catalog and maps of psf_e1/psf_e2

# %%
reload(bas)
bas.titles_avg(im3['tile'], im3['ra'], im3['dec'], im3['im3shape_r_psf_e1_sky_mean'], 
               im3['im3shape_r_psf_e2_sky_mean'], 'tiles_all_v7_psf.npz')

# %%
reload(bas)
bas.plot_tiles_Ng_Ns('tiles_all_v7_plus_numbers_gold.npz', estd=1)
# Out:
# Removing all tiles with error on <e1> and <e2> larger than 1.0e+00
# All tiles: <e1> = -7.5672e-05 <e2> = 1.2262e-03
# # of tiles included 288 out of 288
# Removed tiles <e1> = -7.5672e-05 <e2> = 1.2262e-03

# %% [markdown]
# # 10. Cutout size along with mask fraction

# %%
print np.unique(im3['im3shape_r_stamp_size'])
# Out:
# [32 48 64 96]

# %%
for ss in [32, 48, 64, 96]:
    con = (im3['im3shape_r_stamp_size'] == ss)
    pl.figure(99)
    xxx = pl.hist(im3['mask_fraction'][con], 20, histtype='step', label='SS=%d'%ss)
pl.legend(loc=0)

# %%
for ss in [32, 48, 64, 96]:
    A = ss * ss
    print A, A*0.3
# Out:
# 1024 307.2
# 2304 691.2
# 4096 1228.8
# 9216 2764.8

# %%
con = (im3['im3shape_r_stamp_size'] == 32) & (im3['mask_fraction'] > 0.25)
print con[con].shape[0] * 1.0 / con.shape[0]
# Out:
# 0.125318552327

# %%
e1_avg = []
e2_avg = []
e1_std = []
e2_std = []
N = []
mf_arr = np.arange(0.1, 0.5, 0.05)
mff3 = []
mff4 = []
for mf3 in mf_arr:
    for mf4 in mf_arr:
        con = ((im3['im3shape_r_stamp_size'] == 32) & (im3['mask_fraction'] > mf3)) | \
            ((im3['im3shape_r_stamp_size'] == 48) & (im3['mask_fraction'] > mf4))
        e1_avg.append(im3['e1'][~con].mean())
        e2_avg.append(im3['e2'][~con].mean())
        e1_std.append(im3['e1'][~con].std())
        e2_std.append(im3['e2'][~con].std())
        N.append(con[~con].shape[0])
        mff3.append(mf3)
        mff4.append(mf4)
e1_avg = np.array(e1_avg)
e2_avg = np.array(e2_avg)
e1_std = np.array(e1_std)
e2_std = np.array(e2_std)
N = np.array(N)
e1_std = e1_std / np.sqrt(N)
e2_std = e2_std / np.sqrt(N)
        #print con[~con].shape[0] * 1.0 / con.shape[0], im3['e1'][~con].mean(), im3['e2'][~con].mean()

# %%
for t, u,v,w,x,y,z in zip(e1_avg, e2_avg, e1_std, e2_std, N*1./im3.shape[0], mff3, mff4):
    if abs(t) < 6e-4 and abs(u) < 6e-4:
        print t, u, v, w, x, y, z
# Out:
# -0.000543673100904 0.000325955113408 0.000240823921365 0.000244661275137 0.466107102039 0.1 0.1
# -0.000519827844501 0.00032000682508 0.000236289472198 0.000239852633576 0.486953326769 0.1 0.15
# -0.000551723153213 0.000158483546379 0.000232386103106 0.000236066794109 0.491223331855 0.15 0.1
# -0.000528719754591 0.000159644738496 0.000228328161296 0.000231756600611 0.512069556586 0.15 0.15
# -0.000438063796422 0.000526433651518 0.000222228497895 0.000225315926832 0.553417581789 0.15 0.2
# -0.000579172615612 -6.47179716248e-05 0.000213445056593 0.000216842962292 0.568984060751 0.2 0.15
# -0.000493552461411 0.000283067100059 0.000208569393075 0.000211654741097 0.610332085954 0.2 0.2
# -0.000580810775981 0.000240679588542 0.000197099978879 0.000200163491279 0.66988004516 0.25 0.2
# -0.000577651088894 0.000565131698492 0.000193478836088 0.000196436674927 0.714619900556 0.25 0.25
# -0.000464083635564 0.00054973530043 0.000179332558778 0.000182070730186 0.836394733732 0.35 0.3
# -0.000474154811227 0.000520794421805 0.000176736183526 0.000179440092548 0.858121807457 0.4 0.3
# -0.000496969903873 0.00052014219386 0.000175152581406 0.000177830266309 0.87216030489 0.45 0.3

# %%
pl.figure(figsize=(24, 5))
pl.subplot(131)
pl.title(r'$\langle e_1 \rangle$')
pl.imshow(e1_avg.reshape(mf_arr.shape[0], mf_arr.shape[0]), interpolation='none', origin='lower')
pl.xticks(range(mf_arr.shape[0]), ['%.1f'%i for i in mf_arr])
pl.yticks(range(mf_arr.shape[0]), ['%.1f'%i for i in mf_arr])
pl.ylabel('Mask fraction (SS=32)')
pl.xlabel('Mask fraction (SS=48)')
pl.colorbar(shrink=0.9)
pl.subplot(132)
pl.title(r'$\sigma_{e_1}$')
pl.imshow(e1_std.reshape(mf_arr.shape[0], mf_arr.shape[0]), interpolation='none', origin='lower')
pl.xticks(range(mf_arr.shape[0]), ['%.1f'%i for i in mf_arr])
pl.yticks(range(mf_arr.shape[0]), ['%.1f'%i for i in mf_arr])
pl.xlabel('Mask fraction (SS=48)')
#pl.ylabel('Mask fraction (SS=32)')
pl.colorbar(shrink=0.9)
pl.subplot(133)
pl.title(r'$\langle e_1 \rangle / \sigma_{e_1}$')
pl.imshow((e1_avg/e1_std).reshape(mf_arr.shape[0], mf_arr.shape[0]), interpolation='none', origin='lower')
pl.xticks(range(mf_arr.shape[0]), ['%.1f'%i for i in mf_arr])
pl.yticks(range(mf_arr.shape[0]), ['%.1f'%i for i in mf_arr])
pl.xlabel('Mask fraction (SS=48)')
#pl.ylabel('Mask fraction (SS=32)')
pl.colorbar(shrink=0.9)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x51fcccb0>

# %%
pl.figure(figsize=(24, 5))
pl.subplot(131)
pl.title(r'$\langle e_2 \rangle$')
pl.imshow(e2_avg.reshape(mf_arr.shape[0], mf_arr.shape[0]), interpolation='none', origin='lower')
pl.xticks(range(mf_arr.shape[0]), ['%.1f'%i for i in mf_arr])
pl.yticks(range(mf_arr.shape[0]), ['%.1f'%i for i in mf_arr])
pl.xlabel('Mask fraction (SS=48)')
pl.ylabel('Mask fraction (SS=32)')
pl.colorbar(shrink=0.9)
pl.subplot(132)
pl.title(r'$\sigma_{e_2}$')
pl.imshow(e2_std.reshape(mf_arr.shape[0], mf_arr.shape[0]), interpolation='none', origin='lower')
pl.xticks(range(mf_arr.shape[0]), ['%.1f'%i for i in mf_arr])
pl.yticks(range(mf_arr.shape[0]), ['%.1f'%i for i in mf_arr])
pl.xlabel('Mask fraction (SS=48)')
#pl.ylabel('Mask fraction (SS=32')
pl.colorbar(shrink=0.9)
pl.subplot(133)
pl.title(r'$\langle e_2 \rangle / \sigma_{e_2}$')
pl.imshow((e2_avg/e2_std).reshape(mf_arr.shape[0], mf_arr.shape[0]), interpolation='none', origin='lower')
pl.xticks(range(mf_arr.shape[0]), ['%.1f'%i for i in mf_arr])
pl.yticks(range(mf_arr.shape[0]), ['%.1f'%i for i in mf_arr])
pl.xlabel('Mask fraction (SS=48)')
#pl.ylabel('Mask fraction (SS=32)')
pl.colorbar(shrink=0.9)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x512962d8>

# %%
pl.figure(figsize=(8,8))
pl.title('Fraction of galaxies')
pl.imshow((N*1. / im3.shape[0]).reshape(mf_arr.shape[0], mf_arr.shape[0]), interpolation='none', origin='lower')
pl.xticks(range(mf_arr.shape[0]), ['%.1f'%i for i in mf_arr])
pl.yticks(range(mf_arr.shape[0]), ['%.1f'%i for i in mf_arr])
pl.xlabel('Mask fraction (SS=48)')
pl.ylabel('Mask fraction (SS=32)')
pl.colorbar(shrink=0.8)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x51539ab8>

# %% [markdown]
# # 11. Disc A

# %%
xxx = pl.hist(im3['disc_A'], 30, range=(-2, 5))
pl.xlabel('Disc A')

# %%
xxx = pl.hist(im3['bulge_A'], 30, range=(-2e2, 5e2))
pl.xlabel('Bulge A')

# %%
bas.plot_q(im3['disc_A'], im3['e1'], im3['e2'], -1, 1, 10, 'Disk A', xlim=None, ylim=(-0.01, 0.01))

# %%
bas.plot_q(im3['bulge_A'], im3['e1'], im3['e2'], -2e2, 5e2, 10, 'Bulge A', xlim=None, ylim=(-0.01, 0.01))

# %%
bd_A = im3['disc_A']/im3['bulge_A']

# %%
xxx = pl.hist(bd_A, range=(-.06, .05))

# %%
bas.plot_q(bd_A, im3['e1'], im3['e2'], -0.03, 0.02, 20, 'Bulge A/Disc A', xlim=None, ylim=(-0.01, 0.01))

# %%
BT = abs(im3['im3shape_r_bulge_flux']) / (abs(im3['im3shape_r_bulge_flux']) + abs(im3['im3shape_r_disc_flux']))
BT_neg = (im3['im3shape_r_bulge_flux']) / (abs(im3['im3shape_r_bulge_flux']) + abs(im3['im3shape_r_disc_flux']))
DT_neg = (im3['im3shape_r_disc_flux']) / (abs(im3['im3shape_r_bulge_flux']) + abs(im3['im3shape_r_disc_flux']))

# %% [markdown]
# # 12a. Flags fA to fF are based on the following criteria

# %%
flags_ = []
for dA in np.arange(-1, 0, 0.05):
    c = (im3['disc_A'] > dA) & (im3['bulge_A'] > -2e9) & (im3['radius'] < 4.0) & (DT_neg > -0.6)
    frac = c[c].shape[0] * 1./ c.shape[0]
    avge1, avge2 = im3['e1'][c].mean(), im3['e2'][c].mean()
    if frac > 0.7 and abs(avge1) < 7e-4 and abs(avge2) < 7e-4:
        print 'Disk_A=%.2f <e1>=%.2e <e2>=%.2e fraction=%.2f'%(dA, avge1, avge2, frac)
        flags_.append(c)
# Out:
# Disk_A=-0.65 <e1>=-3.96e-04 <e2>=6.95e-04 fraction=0.93
# Disk_A=-0.60 <e1>=-4.14e-04 <e2>=6.17e-04 fraction=0.91
# Disk_A=-0.55 <e1>=-4.84e-04 <e2>=5.87e-04 fraction=0.89
# Disk_A=-0.50 <e1>=-5.51e-04 <e2>=4.96e-04 fraction=0.86
# Disk_A=-0.45 <e1>=-5.80e-04 <e2>=3.77e-04 fraction=0.83
# Disk_A=-0.40 <e1>=-5.72e-04 <e2>=3.86e-04 fraction=0.78

# %% [markdown]
# # 12b. Flag fG is based on the following

# %%
con = (im3['im3shape_r_stamp_size']==48) & (im3['radius'] > 3.5)
print im3['e1'][~con].mean(), im3['e2'][~con].mean(), con[~con].shape[0] * 1. / con.shape[0]
# Out:
# -0.000552229562407 0.000563599992334 0.950566027039

# %%
flags_.append(~con)
flags_ = np.array(flags_)

# %%
print flags_.shape
# Out:
# (7, 1869787)

# %%
import mytools as my

# %%
flag_array = [i for i in flags_]
flag_names = ['f%s'%chr(i) for i in range(65, 65+flags_.shape[0])]
flag_format = ['I' for i in range(flags_.shape[0])]

# %%
print flag_names
# Out:
# ['fA', 'fB', 'fC', 'fD', 'fE', 'fF', 'fG']

# %%
fits.writeto('error_info.fits', im3)

# %%
my.merge_fits_tables_array('error_info.fits', flag_array, flag_names, flag_format, 'im3shape_v7_Error_Info_ExtFlags.fits')
os.system('rm -f error_info.fits')
# Out:
# 0

# %%
bas.plot_avg(im3['MAG_AUTO_I'], im3['e1'], 19, 25, 20, 'Magnitude I', 'e1', 
             'r', figsize=(6,6), xlim=None, ylim=(-0.008, 0.005))

# %%
bas.plot_avg(im3['MAG_AUTO_I'], im3['e2'], 19, 25, 20, 'Magnitude I', 'e2', 
             'r', figsize=(6,6), xlim=None, ylim=(-0.008, 0.005))

# %%
for mrl in np.arange(16, 22, 0.5):
    for mru in np.arange(25, 21, -0.5):
        con = (im3['MAG_AUTO_I'] > mrl) &  (im3['MAG_AUTO_I'] < mru)
        frac = con[con].shape[0] * 1.0 / con.shape[0]
        if frac > 0.5 and im3['e2'][con].mean() < 0.001:
            print mrl, mru, im3['e1'][con].mean(), im3['e2'][con].mean(), frac
# Out:
# 16.0 23.0 -6.04668419065e-05 0.000917363945223 0.905273167478
# 16.0
#  22.5 -1.88185831115e-05 0.000934763395318 0.726500932994
# 16.0
#  22.0 5.38758897802e-05 0.000844662040356 0.516207995884
# 16.5
#  23.0 -6.05212130874e-05 0.000917441439611 0.905272632658
# 16.5
#  22.5 -1.88863029199e-05 0.000934859971802 0.726500398174
# 16.5
#  22.0 5.37806575471e-05 0.000844797866883 0.516207461064
# 17.0
#  23.0 -6.05450689988e-05 0.000917143622846 0.905264075534
# 17.0
#  22.5 -1.89155387947e-05 0.000934489074635 0.726491841049
# 17.0
#  22.0 5.37407159585e-05 0.000844274377902 0.516198903939
# 17.5
#  23.0 -5.88931469234e-05 0.000917549160284 0.905171551626
# 17.5
#  22.5 -1.68517640091e-05 0.000934996627178 0.726399317141
# 17.5
#  22.0 5.66584226442e-05 0.000844972564977 0.516106380032
# 18.0
#  23.0 -6.04911307765e-05 0.000921525558546 0.904740486483
# 18.0
#  22.5 -1.88182936886e-05 0.000939962587443 0.725968251999
# 18.0
#  22.0 5.39513889846e-05 0.00085188839584 0.515675314889
# 18.5
#  23.0 -5.35909031734e-05 0.00091573414289 0.903071847221
# 18.5
#  22.5 -1.01189403974e-05 0.000932784204916 0.724299612737
# 18.5
#  22.0 6.64460994116e-05 0.000841487239606 0.514006675627
# 19.0
#  23.0 -1.29469785046e-05 0.000919213189248 0.897731131942
# 19.0
#  22.5 4.09541988394e-05 0.000937254985879 0.718958897457
# 19.0
#  22.0 0.000139437812732 0.000846847764719 0.508665960347
# 19.5
#  23.0 1.26810478239e-05 0.000916974837763 0.883449291283
# 19.5
#  22.5 7.41763244885e-05 0.000934814435344 0.704677056798
# 20.0
#  25.0 -7.8387217136e-05 0.000975838084329 0.947708482303
# 20.0 24.5 -7.8387217136e-05
# 0.000975838084329 0.947708482303
# 20.0 24.0 -7.90836820918e-05 0.000980754123391 0.947379567833
# 20.0
#  23.5 -9.66397620778e-05 0.000957202159959 0.93572262509
# 20.0 23.0
# -4.12176464388e-05 0.000836599091255 0.852981649781
# 20.0 22.5
# 8.7649254348e-06 0.000833932565628 0.674209415297
# 20.5
#  23.5 -0.000124211008064 0.000988449155479 0.879931778326
# 20.5
#  23.0 -6.77718523709e-05 0.000862648911363 0.797190803017
# 20.5
#  22.5 -2.09563663851e-05 0.000867272297545 0.618418568532
# 21.0
#  23.0 -7.83255861872e-05 0.000886801750554 0.706217874015
# 21.0
#  22.5 -2.70125233357e-05 0.000900408925129 0.52744563953
# 21.5
#  23.0 -0.000240876221977 0.000826674643622 0.571626072916

# %% [markdown]
# # 13a. Centroid Offset

# %%
ra_off = im3['im3shape_r_ra_as']
dec_off = im3['im3shape_r_dec_as']

# %%
off = np.sqrt(ra_off**2 + dec_off**2)
print ra_off.min(), ra_off.max(), dec_off.min(), dec_off.max()
# Out:
# -0.590779 0.59864 -0.599053 0.595428

# %%
xxx = pl.hist(ra_off, 100, range=(-0.2, 0.2))

# %%
xxx = pl.hist(dec_off, 100, range=(-0.2, 0.2))

# %%
bas.plot_avg(ra_off, off, -0.03, 0.03, 20, 'RA Offset', 'Offset', 'r', figsize=(6,6), xlim=None)

# %%
bas.plot_avg(dec_off, off, -0.03, 0.03, 20, 'DEC Offset', 'Offset', 'r', figsize=(6,6), xlim=None)

# %%
bas.plot_avg(ra_off, im3['e1'], -0.1, 0.1, 20, 'RA Offset', '<e1>', 'r', figsize=(6,6), xlim=None)

# %%
bas.plot_avg(dec_off, im3['e1'], -0.1, 0.1, 20, 'DEC Offset', '<e1>', 'r', figsize=(6,6), xlim=None)

# %%
bas.plot_avg(off, im3['e1'], -0.1, 0.1, 50, 'Offset', '<e1>', 'r', figsize=(6,6), xlim=None)

# %%
bas.plot_avg(ra_off, im3['e2'], -0.1, 0.1, 20, 'RA Offset', '<e2>', 'r', figsize=(6,6), xlim=None)

# %%
bas.plot_avg(dec_off, im3['e2'], -0.1, 0.1, 20, 'DEC Offset', '<e2>', 'r', figsize=(6,6), xlim=None)

# %%
bas.plot_avg(off, im3['e2'], 0., 0.1, 20, 'Offset', '<e2>', 'r', figsize=(6,6), xlim=None)

# %% [markdown]
# # 13b. $<e>$ in RA-DEC offset plane

# %%
reload(bas)
avg_e1 = bas.avg_2d(ra_off, dec_off, im3['e1'], 40, 40, 'mean', -0.05, 0.05, 
                    r'$\langle e_1 \rangle$', 60, 'RA offset', 'DEC offset')

# %%
reload(bas)
avg_e2 = bas.avg_2d(ra_off, dec_off, im3['e2'], 40, 40, 'mean', -0.05, 0.05, 
                    r'$\langle e_2 \rangle$', 60, 'RA offset', 'DEC offset')

# %% [markdown]
# # PLEASE STOP!

# %%
c1 = (abs(ra_off) < 0.05) | (abs(dec_off) < 0.05)
print im3['e1'][c1].mean(), im3['e2'][c1].mean()
# Out:
# 4.49723495009e-06 0.000906086127902

# %%
for i in np.arange(0.01, 0.31, 0.02):
    c = (off < i)
    print im3['e1'][c].mean(), im3['e2'][c].mean(), c[c].shape[0] * 1. / c.shape[0], c[c].shape[0], c.shape[0]
# Out:
# 0.00181650975794 0.000912946506687 0.05156202284 96410 1869787
# 0.000244517454128 0.00111060671919
# 0.293865557949 549466 1869787
# -6.51819601547e-05
# 0.00116553689146 0.506782323334 947575 1869787
# -8.1569863365e-05
#  0.000895403045589 0.658164807007 1230628 1869787
# -6.28225521582e-05
# 0.000933898869647 0.762932890217 1426522 1869787
# -0.000125031989568
# 0.000973620034174 0.834830919244 1560956 1869787
# -6.94356750883e-05 0.00100979570452
# 0.884130652315 1653136 1869787
# 6.13753446154e-06 0.000956724552843 0.918120085336 1716689 1869787
# -5.76965796435e-05
#  0.00095414346262 0.941344121015 1760113 1869787
# -8.00834157281e-05 0.000965835102379 0.957390333765 1790116 1869787
# -7.67483770689e-05
# 0.000953290241649 0.968626907771 1811126 1869787
# -7.00870868837e-05 0.000972762685339 0.976724086754 1826266 1869787
# -7.8758634568e-05
# 0.000993437722979 0.982510842144 1837086 1869787
# -8.59961043384e-05 0.000982892663817 0.986685114401 1844891 1869787
# -8.54905475138e-05
# 0.000978209641054 0.989704174861 1850536 1869787

# %%
reload(bas)
avg_e2 = bas.avg_2d(ra_off, dec_off, im3['mean_psf_e1_sky'], 20, 20, 'mean', -0.01, 0.01, r'PSF $\langle e_1 \rangle$', 60, 
                    'RA offset', 'DEC offset')

# %%
cons = [(ra_off < 0) & (dec_off < 0), (ra_off > 0) & (dec_off > 0), (ra_off > 0) & (dec_off < 0), (ra_off < 0) & (dec_off > 0)]
for con, c, lab in zip(cons, ['r', 'g', 'b', 'k'], ['BL', 'TR', 'BR', 'TL']):
    bas.plot_psf(im3['mean_psf_e1_sky'][con], im3['e1'][con], -0.01, 0.03, 10, lab, c, 'E1', ylim=(-0.005, 0.009))

# %%
reload(bas)
cons = [(ra_off < 0) & (dec_off < 0), (ra_off > 0) & (dec_off > 0), (ra_off > 0) & (dec_off < 0), (ra_off < 0) & (dec_off > 0), \
        abs(ra_off) > -1]
for con, c, lab in zip(cons, ['r', 'g', 'b', 'k', 'm'], ['BL', 'TR', 'BR', 'TL', 'All']):
    bas.plot_psf(im3['mean_psf_e2_sky'][con], im3['e2'][con], -0.01, 0.03, 10, lab, c, 'E2', ylim=(-0.04, 0.04))

# %% [markdown]
# # 100. Compare with im3shape v6 : ERROR_FLAG=0 & INFO_FLAG=0 for SPT-E region only

# %%
spte = (iim3['ra'] > 60) & (iim3['ra'] < 90) & (iim3['dec'] > -62) & (iim3['dec'] < -42)
print spte[spte].shape
# Out:
# (2155291,)

# %%
bas.plot_rad(iim3[spte]['radius'], iim3[spte]['e1'], iim3[spte]['e2'], 7, 10)

# %%
bas.plot_maskfrac(iim3[spte]['MASK_FRACTION'],  iim3[spte]['e1'], iim3[spte]['e2'])

# %%
bas.titles_avg(iim3[spte]['tilename'], iim3[spte]['ra'], iim3[spte]['dec'], iim3[spte]['e1'], iim3[spte]['e2'],
               'tiles_info_spte.npz')

# %%
bas.plot_tiles('tiles_info_spte.npz')
