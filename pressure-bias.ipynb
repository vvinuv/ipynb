# %%
import os
os.chdir('/media/star3/vinu/maps/theory')

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import estimate_avg_pressure as press

# %%
import mpld3

# %%
mpld3.disable_notebook()

# %% [markdown]
# ## 1. Random measured from randomized y-map

# %%
reload(press)
press.main(1, 1)
# Out:
# Rmin=2.50 Mpc Rmax=20.00 Mpc
# <bP> = 1.40e-07 \pm 6.70e-08
# Rmin=2.79 Mpc Rmax=20.00 Mpc
# <bP> = 1.10e-07 \pm 5.23e-08
# Rmin=0.86 Mpc Rmax=20.00 Mpc
# <bP> = 6.44e-08 \pm 4.28e-08
# Rmin=2.19 Mpc Rmax=20.00 Mpc
# <bP> = 4.50e-08 \pm 7.12e-08
# Rmin=3.63 Mpc Rmax=20.00 Mpc
# <bP> = 1.69e-07 \pm 1.02e-07
# Jackniffe total > 6.03e-08 \pm 3.22e-08
# Full Covariance total > 8.08e-08 \pm 2.41e-08
# PCA total > 9.22e-08 \pm 2.65e-08

# %% [markdown]
# ## 2. Random measured from randomized y map. Now Rmin=1 and Rmax=10 for groups with logM < 13 and Rmin=4 and Rmax=20Mpc for logM > 13

# %%
reload(press)
#In get_measured_ycorr() chnages the file name jack_*npz
press.main(1, 1)
# Out:
# Rmin=1.00 Mpc Rmax=10.00 Mpc
# <bP> = 1.31e-07 \pm 6.30e-08
# Rmin=1.00 Mpc Rmax=10.00 Mpc
# <bP> = 8.67e-08 \pm 4.82e-08
# Rmin=1.00 Mpc Rmax=10.00 Mpc
# <bP> = 6.32e-08 \pm 4.03e-08
# Rmin=4.00 Mpc Rmax=20.00 Mpc
# <bP> = 4.58e-08 \pm 7.80e-08
# Rmin=4.00 Mpc Rmax=20.00 Mpc
# <bP> = 1.69e-07 \pm 1.02e-07
# Jackniffe total > 7.40e-08 \pm 2.75e-08
# Full Covariance total > 8.07e-08 \pm 2.41e-08
# PCA total > 8.53e-08 \pm 2.53e-08

# %% [markdown]
# ## 3. Random measured from random points. In each Jackk realization weighted average is calculated

# %%
reload(press)
press.main(1, 1)
# Out:
# Rmin=2.50 Mpc Rmax=20.00 Mpc
# <bP> = 1.74e-07 \pm 6.62e-08
# Rmin=2.79 Mpc Rmax=20.00 Mpc
# <bP> = 1.38e-07 \pm 5.18e-08
# Rmin=0.86 Mpc Rmax=20.00 Mpc
# <bP> = 8.27e-08 \pm 4.13e-08
# Rmin=2.19 Mpc Rmax=20.00 Mpc
# <bP> = 8.96e-08 \pm 6.96e-08
# Rmin=3.63 Mpc Rmax=20.00 Mpc
# <bP> = 1.98e-07 \pm 9.81e-08
# Jackniffe total > 1.12e-07 \pm 3.19e-08
# Full Covariance total > 1.07e-07 \pm 2.38e-08
# PCA total > 1.19e-07 \pm 2.58e-08

# %% [markdown]
# ## 4. Random measured from random points. Now Rmin=1 and Rmax=10 for groups with logM < 13 and Rmin=4 and Rmax=20Mpc for logM > 13

# %%
reload(press)
press.main(1, 1)
# Out:
# Rmin=1.00 Mpc Rmax=10.00 Mpc
# <bP> = 1.67e-07 \pm 6.27e-08
# Rmin=1.00 Mpc Rmax=10.00 Mpc
# <bP> = 1.27e-07 \pm 4.72e-08
# Rmin=1.00 Mpc Rmax=10.00 Mpc
# <bP> = 8.18e-08 \pm 3.91e-08
# Rmin=4.00 Mpc Rmax=20.00 Mpc
# <bP> = 6.17e-08 \pm 7.59e-08
# Rmin=4.00 Mpc Rmax=20.00 Mpc
# <bP> = 1.98e-07 \pm 9.81e-08
# Jackniffe total > 1.09e-07 \pm 2.72e-08
# Full Covariance total > 1.07e-07 \pm 2.37e-08
# PCA total > 1.13e-07 \pm 2.47e-08

# %% [markdown]
# ## Adam's comment : Null chi2

# %% [markdown]
# #### Null map

# %%
reload(press)
for mmin, mmax in zip([11, 12, 13, 14, 14.5], [12, 13, 14, 14.5, 16]):
    press.null_chi2_full_profile('ed', mmin, mmax, 8)
# Out:
# log M=11.0-12.0, Null chi2 > 3.41 \pm 4.24
# log M=12.0-13.0, Null chi2 > 8.29 \pm 4.24
# log M=13.0-14.0, Null chi2 > 12.15 \pm 4.24
# log M=14.0-14.5, Null chi2 > 11.87 \pm 4.24
# log M=14.5-16.0, Null chi2 > 8.73 \pm 4.24

# %%
reload(press)
for mmin, mmax in zip([11, 12, 13, 14, 14.5], [12, 13, 14, 14.5, 16]):
    press.null_chi2_full_profile('ed', mmin, mmax, 8)
# Out:
# log M=11.0-12.0, Null chi2 > 3.16 \pm 4.24
# log M=12.0-13.0, Null chi2 > 7.20 \pm 4.24
# log M=13.0-14.0, Null chi2 > 9.72 \pm 4.24
# log M=14.0-14.5, Null chi2 > 10.08 \pm 4.24
# log M=14.5-16.0, Null chi2 > 8.73 \pm 4.24

# %% [markdown]
# ### Signal map

# %%
reload(press)
for mmin, mmax in zip([11, 12, 13, 14, 14.5], [12, 13, 14, 14.5, 16]):
    press.null_chi2_full_profile('bd', mmin, mmax, 8)
# Out:
# log M=11.0-12.0, Null chi2 > 13.00
# log M=12.0-13.0, Null chi2 > 16.35
# log M=13.0-14.0, Null chi2 > 8.88
# log M=14.0-14.5, Null chi2 > 61.15
# log M=14.5-16.0, Null chi2 > 111.94

# %% [markdown]
# ## Null & Model $\chi^2$ values for the two halo terms for all mass bins. Individual chi2 values are estimated based on full covariance matrix. The final $\chi^2$ is measured using the mass covariance without applying any regularizations.

# %%
reload(press)
press.main('bd', 0, 0)
# Out:
# 11.0 - 12.0
# Number of data points (dof) 6
# Model chi2 > 0.98
# Null chi2 > 8.22 \pm 3.46
# <bP> = 1.67e-07 \pm 6.28e-08
#
# 12.0 - 13.0
# Number of data points (dof) 4
# Model chi2 > 4.81
# Null chi2 > 10.74 \pm 2.83
# <bP> = 1.27e-07 \pm 4.72e-08
#
# 13.0 - 14.0
# Number of data points (dof) 3
# Model chi2 > 6.19
# Null chi2 > 3.65 \pm 2.45
# <bP> = 7.43e-08 \pm 3.94e-08
#
# 14.0 - 14.5
# Number of data points (dof) 3
# Model chi2 > 3.34
# Null chi2 > 2.77 \pm 2.45
# <bP> = 6.17e-08 \pm 7.58e-08
#
# 14.5 - 16.0
# Number of data points (dof) 2
# Model chi2 > 0.47
# Null chi2 > 4.11 \pm 2.00
# <bP> = 2.41e-07 \pm 1.19e-07
#
# Jackknife Final (No mass covariance) > 1.08e-07 \pm 2.82e-08
# Full Covariance Final (No mass covariance) > 1.05e-07 \pm 2.43e-08
# PCA Final (No mass covariance) > 1.10e-07 \pm 2.51e-08
#
# Jackknife Final (Mass covaraince) > 8.51e-08 \pm 4.23e-08
# Full Covariance Final (Mass covariance) > 7.35e-08 \pm 3.76e-08
# ...

# %% [markdown]
# ## Bhuv's comment on minimum radius

# %%
reload(press)
press.main('bd', 0, 1)
# Out:
# 11.0 - 12.0
# Number of data points (dof) 3
# Model chi2 > 0.98
# Null chi2 > 7.10 \pm 2.45
# <bP> = 1.70e-07 \pm 6.61e-08
#
# 12.0 - 13.0
# Number of data points (dof) 3
# Model chi2 > 4.27
# Null chi2 > 10.11 \pm 2.45
# <bP> = 1.15e-07 \pm 6.13e-08
#
# 13.0 - 14.0
# Number of data points (dof) 3
# Model chi2 > 6.19
# Null chi2 > 3.65 \pm 2.45
# <bP> = 7.43e-08 \pm 3.94e-08
#
# 14.0 - 14.5
# Number of data points (dof) 3
# Model chi2 > 3.34
# Null chi2 > 2.77 \pm 2.45
# <bP> = 6.17e-08 \pm 7.58e-08
#
# 14.5 - 16.0
# Number of data points (dof) 3
# Model chi2 > 0.47
# Null chi2 > 5.49 \pm 2.45
# <bP> = 1.98e-07 \pm 9.79e-08
#
# Jackknife Final (No mass covariance) > 1.08e-07 \pm 2.83e-08
# Full Covariance Final (No mass covariance) > 1.07e-07 \pm 2.49e-08
# PCA Final (No mass covariance) > 1.05e-07 \pm 2.66e-08
#
# Jackknife Final (Mass covaraince) > 8.81e-08 \pm 4.18e-08
# Full Covariance Final (Mass covariance) > 7.08e-08 \pm 3.74e-08
# ...

# %%
reload(press)
press.main('bd', 0, 1)
# Out:
# 11.0 - 12.0
# Number of data points (dof) 2
# Model chi2 > 0.33
# Null chi2 > 3.10 \pm 2.00
# <bP> = 1.52e-07 \pm 9.42e-08
#
# 12.0 - 13.0
# Number of data points (dof) 2
# Model chi2 > 2.18
# Null chi2 > 1.80 \pm 2.00
# <bP> = 9.33e-08 \pm 7.30e-08
#
# 13.0 - 14.0
# Number of data points (dof) 2
# Model chi2 > 4.26
# Null chi2 > 2.84 \pm 2.00
# <bP> = 8.41e-08 \pm 5.03e-08
#
# 14.0 - 14.5
# Number of data points (dof) 3
# Model chi2 > 3.34
# Null chi2 > 2.77 \pm 2.45
# <bP> = 6.17e-08 \pm 7.58e-08
#
# 14.5 - 16.0
# Number of data points (dof) 3
# Model chi2 > 0.47
# Null chi2 > 5.49 \pm 2.45
# <bP> = 1.98e-07 \pm 9.79e-08
#
# Jackknife Final (No mass covariance) > 1.08e-07 \pm 3.11e-08
# Full Covariance Final (No mass covariance) > 9.32e-08 \pm 2.81e-08
# PCA Final (No mass covariance) > 1.02e-07 \pm 3.20e-08
#
# Jackknife Final (Mass covaraince) > 9.63e-08 \pm 4.70e-08
# Full Covariance Final (Mass covariance) > 8.31e-08 \pm 4.40e-08
# ...

# %%
reload(press)
press.main('bd', 0, 1)
# Out:
# 11.0 - 12.0
# Number of data points (dof) 2
# Model chi2 > 0.33
# Null chi2 > 3.10 \pm 2.00
# <bP> = 1.52e-07 \pm 9.42e-08
#
# 12.0 - 13.0
# Number of data points (dof) 2
# Model chi2 > 2.18
# Null chi2 > 1.80 \pm 2.00
# <bP> = 9.33e-08 \pm 7.30e-08
#
# 13.0 - 14.0
# Number of data points (dof) 2
# Model chi2 > 4.26
# Null chi2 > 2.84 \pm 2.00
# <bP> = 8.41e-08 \pm 5.03e-08
#
# 14.0 - 14.5
# Number of data points (dof) 3
# Model chi2 > 3.34
# Null chi2 > 2.77 \pm 2.45
# <bP> = 6.17e-08 \pm 7.58e-08
#
# 14.5 - 16.0
# Number of data points (dof) 3
# Model chi2 > 0.47
# Null chi2 > 5.49 \pm 2.45
# <bP> = 1.98e-07 \pm 9.79e-08
#
# Jackknife Final (No mass covariance) > 1.08e-07 \pm 3.11e-08
# Full Covariance Final (No mass covariance) > 9.32e-08 \pm 2.81e-08
# PCA Final (No mass covariance) > 1.02e-07 \pm 3.20e-08
#
# Jackknife Final (Mass covaraince) > 9.63e-08 \pm 4.70e-08
# Full Covariance Final (Mass covariance) > 8.31e-08 \pm 4.40e-08
# ...

# %%
reload(press)
press.main('bd', 0, 1)
# Out:
# 11.0 - 12.0
# Number of data points (dof) 2
# Model chi2 > 0.33
# Null chi2 > 3.10 \pm 2.00
# <bP> = 1.52e-07 \pm 9.42e-08
#
# 12.0 - 13.0
# Number of data points (dof) 2
# Model chi2 > 2.18
# Null chi2 > 1.80 \pm 2.00
# <bP> = 9.33e-08 \pm 7.30e-08
#
# 13.0 - 14.0
# Number of data points (dof) 2
# Model chi2 > 4.26
# Null chi2 > 2.84 \pm 2.00
# <bP> = 8.41e-08 \pm 5.03e-08
#
# 14.0 - 14.5
# Number of data points (dof) 3
# Model chi2 > 3.34
# Null chi2 > 2.77 \pm 2.45
# <bP> = 6.17e-08 \pm 7.58e-08
#
# 14.5 - 16.0
# Number of data points (dof) 3
# Model chi2 > 0.47
# Null chi2 > 5.49 \pm 2.45
# <bP> = 1.98e-07 \pm 9.79e-08
#
# Jackknife Final (No mass covariance) > 1.08e-07 \pm 3.11e-08
# Full Covariance Final (No mass covariance) > 9.32e-08 \pm 2.81e-08
# PCA Final (No mass covariance) > 1.02e-07 \pm 3.20e-08
#
# Jackknife Final (Mass covaraince) > 9.63e-08 \pm 4.70e-08
# Full Covariance Final (Mass covariance) > 8.31e-08 \pm 4.40e-08
# ...

# %%
reload(press)
press.main('bd', 0, 1)
# Out:
# 11.0 - 12.0
# Number of data points (dof) 1
# Model chi2 > 0.00
# Null chi2 > 2.03 \pm 1.41
# <bP> = 1.66e-07 \pm 1.16e-07
#
# 12.0 - 13.0
# Number of data points (dof) 1
# Model chi2 > 0.39
# Null chi2 > 1.35 \pm 1.41
# <bP> = 1.04e-07 \pm 8.92e-08
#
# 13.0 - 14.0
# Number of data points (dof) 1
# Model chi2 > 1.03
# Null chi2 > 2.38 \pm 1.41
# <bP> = 9.62e-08 \pm 6.24e-08
#
# 14.0 - 14.5
# Number of data points (dof) 3
# Model chi2 > 3.34
# Null chi2 > 2.77 \pm 2.45
# <bP> = 6.17e-08 \pm 7.58e-08
#
# 14.5 - 16.0
# Number of data points (dof) 3
# Model chi2 > 0.47
# Null chi2 > 5.49 \pm 2.45
# <bP> = 1.98e-07 \pm 9.79e-08
#
# Jackknife Final (No mass covariance) > 1.20e-07 \pm 3.65e-08
# Full Covariance Final (No mass covariance) > 1.16e-07 \pm 3.62e-08
# PCA Final (No mass covariance) > 1.11e-07 \pm 3.69e-08
#
# Jackknife Final (Mass covaraince) > 1.07e-07 \pm 5.48e-08
# Full Covariance Final (Mass covariance) > 1.03e-07 \pm 5.43e-08
# ...

# %%
reload(press)
press.main('bd', 0, 1)
# Out:
# 11.0 - 12.0
# Number of data points (dof) 2
# Model chi2 > 0.67
# Null chi2 > 3.89 \pm 2.00
# <bP> = 1.38e-07 \pm 1.34e-07
#
# 12.0 - 13.0
# Number of data points (dof) 2
# Model chi2 > 0.43
# Null chi2 > 2.89 \pm 2.00
# <bP> = 8.59e-08 \pm 1.12e-07
#
# 13.0 - 14.0
# Number of data points (dof) 2
# Model chi2 > 1.55
# Null chi2 > 2.38 \pm 2.00
# <bP> = 1.05e-07 \pm 7.15e-08
#
# 14.0 - 14.5
# Number of data points (dof) 3
# Model chi2 > 3.34
# Null chi2 > 2.77 \pm 2.45
# <bP> = 6.17e-08 \pm 7.58e-08
#
# 14.5 - 16.0
# Number of data points (dof) 3
# Model chi2 > 0.47
# Null chi2 > 5.49 \pm 2.45
# <bP> = 1.98e-07 \pm 9.79e-08
#
# Jackknife Final (No mass covariance) > 1.20e-07 \pm 4.22e-08
# Full Covariance Final (No mass covariance) > 1.21e-07 \pm 3.45e-08
# PCA Final (No mass covariance) > 1.09e-07 \pm 4.05e-08
#
# Jackknife Final (Mass covaraince) > 1.29e-07 \pm 5.64e-08
# Full Covariance Final (Mass covariance) > 6.62e-08 \pm 5.07e-08
# ...

# %%
reload(press)
press.main('bd', 0, 1)
# Out:
# 11.0 - 12.0
# Number of data points (dof) 1
# Model chi2 > 0.00
# Null chi2 > 2.03 \pm 1.41
# <bP> = 1.66e-07 \pm 1.16e-07
#
# 12.0 - 13.0
# Number of data points (dof) 1
# Model chi2 > 0.39
# Null chi2 > 1.35 \pm 1.41
# <bP> = 1.04e-07 \pm 8.92e-08
#
# 13.0 - 14.0
# Number of data points (dof) 1
# Model chi2 > 1.03
# Null chi2 > 2.38 \pm 1.41
# <bP> = 9.62e-08 \pm 6.24e-08
#
# 14.0 - 14.5
# Number of data points (dof) 3
# Model chi2 > 3.34
# Null chi2 > 2.77 \pm 2.45
# <bP> = 6.17e-08 \pm 7.58e-08
#
# 14.5 - 16.0
# Number of data points (dof) 3
# Model chi2 > 0.47
# Null chi2 > 5.49 \pm 2.45
# <bP> = 1.98e-07 \pm 9.79e-08
#
# Jackknife Final (No mass covariance) > 1.20e-07 \pm 3.65e-08
# Full Covariance Final (No mass covariance) > 1.16e-07 \pm 3.62e-08
# PCA Final (No mass covariance) > 1.11e-07 \pm 3.69e-08
#
# Jackknife Final (Mass covaraince) > 1.07e-07 \pm 5.48e-08
# Full Covariance Final (Mass covariance) > 1.03e-07 \pm 5.43e-08
# ...

# %%
reload(press)
press.main('bd', 0, 1)
# Out:
# 11.0 - 12.0
# Number of data points (dof) 1
# Model chi2 > 0.00
# Null chi2 > 2.03 \pm 1.41
# <bP> = 1.66e-07 \pm 1.16e-07
#
# 12.0 - 13.0
# Number of data points (dof) 1
# Model chi2 > 0.39
# Null chi2 > 1.35 \pm 1.41
# <bP> = 1.04e-07 \pm 8.92e-08
#
# 13.0 - 14.0
# Number of data points (dof) 1
# Model chi2 > 1.03
# Null chi2 > 2.38 \pm 1.41
# <bP> = 9.62e-08 \pm 6.24e-08
#
# 14.0 - 14.5
# Number of data points (dof) 2
# Model chi2 > 0.26
# Null chi2 > 2.37 \pm 2.00
# <bP> = 1.29e-07 \pm 8.66e-08
#
# 14.5 - 16.0
# Number of data points (dof) 2
# Model chi2 > 0.47
# Null chi2 > 4.11 \pm 2.00
# <bP> = 2.41e-07 \pm 1.19e-07
#
# Jackknife Final (No mass covariance) > 1.27e-07 \pm 3.90e-08
# Full Covariance Final (No mass covariance) > 1.28e-07 \pm 3.89e-08
# PCA Final (No mass covariance) > 1.28e-07 \pm 3.89e-08
#
# Jackknife Final (Mass covaraince) > 1.05e-07 \pm 5.81e-08
# Full Covariance Final (Mass covariance) > 1.06e-07 \pm 5.80e-08
# ...

# %%
reload(press)
press.main('bd', 0, 1)
# Out:
# 11.0 - 12.0
# Number of data points (dof) 1
# Model chi2 > 0.00
# Null chi2 > 2.03 \pm 1.41
# <bP> = 1.66e-07 \pm 1.16e-07
#
# 12.0 - 13.0
# Number of data points (dof) 1
# Model chi2 > 0.39
# Null chi2 > 1.35 \pm 1.41
# <bP> = 1.04e-07 \pm 8.92e-08
#
# 13.0 - 14.0
# Number of data points (dof) 1
# Model chi2 > 1.03
# Null chi2 > 2.38 \pm 1.41
# <bP> = 9.62e-08 \pm 6.24e-08
#
# 14.0 - 14.5
# Number of data points (dof) 2
# Model chi2 > 0.26
# Null chi2 > 2.37 \pm 2.00
# <bP> = 1.29e-07 \pm 8.66e-08
#
# 14.5 - 16.0
# Number of data points (dof) 2
# Model chi2 > 0.47
# Null chi2 > 4.11 \pm 2.00
# <bP> = 2.41e-07 \pm 1.19e-07
#
# Jackknife Final (No mass covariance) > 1.27e-07 \pm 3.90e-08
# Full Covariance Final (No mass covariance) > 1.28e-07 \pm 3.89e-08
# PCA Final (No mass covariance) > 1.28e-07 \pm 3.89e-08
#
# Jackknife Final (Mass covaraince) > 1.05e-07 \pm 5.81e-08
# Full Covariance Final (Mass covariance) > 1.06e-07 \pm 5.80e-08
# ...

# %%
reload(press)
press.main('bd', 0, 1)
# Out:
# 11.0 - 12.0
# Number of data points (dof) 1
# Model chi2 > 0.00
# Null chi2 > 2.03 \pm 1.41
# <bP> = 1.66e-07 \pm 1.16e-07
#
# 12.0 - 13.0
# Number of data points (dof) 1
# Model chi2 > 0.39
# Null chi2 > 1.35 \pm 1.41
# <bP> = 1.04e-07 \pm 8.92e-08
#
# 13.0 - 14.0
# Number of data points (dof) 1
# Model chi2 > 1.03
# Null chi2 > 2.38 \pm 1.41
# <bP> = 9.62e-08 \pm 6.24e-08
#
# 14.0 - 14.5
# Number of data points (dof) 2
# Model chi2 > 0.26
# Null chi2 > 2.37 \pm 2.00
# <bP> = 1.29e-07 \pm 8.66e-08
#
# 14.5 - 16.0
# Number of data points (dof) 2
# Model chi2 > 0.47
# Null chi2 > 4.11 \pm 2.00
# <bP> = 2.41e-07 \pm 1.19e-07
#
# Jackknife Final (No mass covariance) > 1.27e-07 \pm 3.90e-08
# Full Covariance Final (No mass covariance) > 1.28e-07 \pm 3.89e-08
# PCA Final (No mass covariance) > 1.28e-07 \pm 3.89e-08
#
# Jackknife Final (Mass covaraince) > 1.05e-07 \pm 5.81e-08
# Full Covariance Final (Mass covariance) > 1.06e-07 \pm 5.80e-08
# ...

# %%
reload(press)
press.main('bd', 0, 1)
# Out:
# 11.0 - 12.0
# Number of data points (dof) 1
# Model chi2 > 0.00
# Null chi2 > 2.03 \pm 1.41
# <bP> = 1.66e-07 \pm 1.16e-07
#
# 12.0 - 13.0
# Number of data points (dof) 1
# Model chi2 > 0.39
# Null chi2 > 1.35 \pm 1.41
# <bP> = 1.04e-07 \pm 8.92e-08
#
# 13.0 - 14.0
# Number of data points (dof) 1
# Model chi2 > 1.03
# Null chi2 > 2.38 \pm 1.41
# <bP> = 9.62e-08 \pm 6.24e-08
#
# 14.0 - 14.5
# Number of data points (dof) 3
# Model chi2 > 0.89
# Null chi2 > 3.02 \pm 2.45
# <bP> = 1.51e-07 \pm 8.99e-08
#
# 14.5 - 16.0
# Number of data points (dof) 3
# Model chi2 > 7.89
# Null chi2 > 9.74 \pm 2.45
# <bP> = 1.53e-07 \pm 1.15e-07
#
# Jackknife Final (No mass covariance) > 1.18e-07 \pm 3.94e-08
# Full Covariance Final (No mass covariance) > 1.19e-07 \pm 3.88e-08
# PCA Final (No mass covariance) > 1.22e-07 \pm 3.90e-08
#
# Jackknife Final (Mass covaraince) > 1.00e-07 \pm 5.93e-08
# Full Covariance Final (Mass covariance) > 9.97e-08 \pm 5.90e-08
# ...
