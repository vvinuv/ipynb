# %%
import os

# %%
os.chdir('/data3/scratch/DES_vinu/DES_catalogs/')

# %%
from astropy.io import fits
import numpy as np
import pylab as pl
import basics as bas

# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 1. Select objects with ERROR_FLAG=0

# %%
im3 = fits.open('im3shape_v6_r_all_cols_only_galaxies_Aug8.fits')[1].data
print im3.shape
e = (im3['error_flag'] == 0) & (im3['snr'] > 0)
im3 = im3[e]
print im3.shape
# Out:
# (11024206,)
# (10253528,)

# %%
print im3.names
# Out:
# ['COADD_OBJECTS_ID', 'RA', 'DEC', 'E1', 'E2', 'SNR', 'OLD_SNR', 'RADIUS', 'ERROR_FLAG', 'INFO_FLAG', 'TILENAME', 'MASK_FRACTION', 'STAMP_SIZE', 'MEAN_PSF_E1_SKY', 'MEAN_PSF_E2_SKY', 'MIN_RESIDUALS', 'MAX_RESIDUALS', 'MODEL_MIN', 'MODEL_MAX', 'LIKELIHOOD', 'BULGE_A', 'DISC_A', 'BULGE_FLUX', 'DISC_FLUX', 'MEAN_FLUX', 'N_EXPOSURE', 'MEAN_RGPP_RP', 'CHI2_PIXEL']

# %% [markdown]
# ### 1a. Plotting $<e_1>$ and $<e_2>$ vs Mask fraction

# %%
bas.plot_maskfrac(im3['MASK_FRACTION'], im3['e1'], im3['e2'])

# %% [markdown]
# ### 1b. Plotting $<e_1>$ and $<e_2>$ vs radius

# %%
bas.plot_rad(im3['radius'], im3['e1'], im3['e2'], 20, 30)

# %% [markdown]
# ### 1c. Plotting quantities per tile

# %%
reload(bas)
# Out:
# <module 'basics' from 'basics.py'>

# %%
bas.plot_tiles('tiles_sn10.npz')

# %% [markdown]
# # Objects with ERROR_FLAG=0 and INFO_FLAG=0

# %%
info_flag = im3['info_flag']

# %%
import mytools as my

# %%
for bit in range(23):
    N =my.isset(info_flag, bit)
    print 'INFO_FLAG = %d N = %d Fraction=%.2f'%(bit, N[N].shape[0], N[N].shape[0] / (1.0 * N.shape[0]))
# Out:
# INFO_FLAG = 0 N = 1427247 Fraction=0.14
# INFO_FLAG = 1 N = 1971742 Fraction=0.19
# INFO_FLAG = 2 N = 4619633 Fraction=0.45
# INFO_FLAG = 3 N = 2453626 Fraction=0.24
# INFO_FLAG = 4 N = 510493 Fraction=0.05
# INFO_FLAG = 5 N = 1804878 Fraction=0.18
# INFO_FLAG = 6 N = 258358 Fraction=0.03
# INFO_FLAG = 7 N = 458462 Fraction=0.04
# INFO_FLAG = 8 N = 783972 Fraction=0.08
# INFO_FLAG = 9 N = 67335 Fraction=0.01
# INFO_FLAG = 10 N = 196177 Fraction=0.02
# INFO_FLAG = 11 N = 213825 Fraction=0.02
# INFO_FLAG = 12 N = 22 Fraction=0.00
# INFO_FLAG = 13 N = 0 Fraction=0.00
# INFO_FLAG = 14 N = 55604 Fraction=0.01
# INFO_FLAG = 15 N = 1114311 Fraction=0.11
# INFO_FLAG = 16 N = 76446 Fraction=0.01
# INFO_FLAG = 17 N = 35079 Fraction=0.00
# INFO_FLAG = 18 N = 0 Fraction=0.00
# INFO_FLAG = 19 N = 48989 Fraction=0.00
# INFO_FLAG = 20 N = 1104249 Fraction=0.11
# INFO_FLAG = 21 N = 161791 Fraction=0.02
# INFO_FLAG = 22 N = 692476 Fraction=0.07

# %%
ie = (im3['info_flag'] == 0)
iim3 = im3[ie]
print iim3.shape
# Out:
# (3073722,)

# %%
bas.plot_rad(iim3['radius'], iim3['e1'], iim3['e2'], 7, 10)

# %%
bas.plot_maskfrac(iim3['MASK_FRACTION'], iim3['e1'], iim3['e2'])

# %%
bas.titles_avg(iim3['tilename'], iim3['ra'], iim3['dec'], iim3['e1'], iim3['e2'], 'tiles_info.npz')

# %%
bas.plot_tiles('tiles_info.npz')

# %% [markdown]
# # ERROR_FLAG=0 & INFO_FLAG=0 for SPT-E region only

# %%
spte = (iim3['ra'] > 60) & (iim3['ra'] < 90) & (iim3['dec'] > -62) & (iim3['dec'] < -42)
print spte[spte].shape
# Out:
# (2155291,)

# %%
bas.plot_rad(iim3[spte]['radius'], iim3[spte]['e1'], iim3[spte]['e2'], 7, 10)

# %%
bas.plot_maskfrac(iim3[spte]['MASK_FRACTION'],  iim3[spte]['e1'], iim3[spte]['e2'])

# %%
bas.titles_avg(iim3[spte]['tilename'], iim3[spte]['ra'], iim3[spte]['dec'], iim3[spte]['e1'], iim3[spte]['e2'], 'tiles_info_spte.npz')

# %%
bas.plot_tiles('tiles_info_spte.npz')

# %% [markdown]
# ## Dependence on the stamp size

# %% [markdown]
# #### ERROR_FLAG=0 and INFO_FLAG=0

# %%
bas.plot_stampsize(iim3['STAMP_SIZE'],  iim3['e1'], iim3['e2'])

# %% [markdown]
# #### Only SPT-E filed

# %%
reload(bas)
bas.plot_stampsize(iim3[spte]['STAMP_SIZE'],  iim3[spte]['e1'], iim3[spte]['e2'])

# %%
reload(bas)
bas.plot_stampsize_radius(iim3[spte]['STAMP_SIZE'],  iim3[spte]['radius'])

# %% [markdown]
# #### Removing small objects with radius < 1.5 arcsec

# %%
crad = spte & (iim3['radius'] > 1.5)

# %%
reload(bas)
bas.plot_stampsize(iim3[crad]['STAMP_SIZE'],  iim3[crad]['e1'], iim3[crad]['e2'])

# %%
bas.plot_rad(iim3[crad]['radius'], iim3[crad]['e1'], iim3[crad]['e2'], 7, 10)

# %% [markdown]
# #### Model_min & Model_max

# %%
import gc
gc.collect()
# Out:
# 9

# %%
mod_min = iim3[spte]['model_min']
mod_min[mod_min < 0].shape
# Out:
# (1694315,)

# %%
pl.figure(figsize=(12,5))
pl.subplot(121)
x = pl.hist(iim3[spte]['model_min'], 40, label='Model Min', color='k', histtype='step')
pl.xlabel('Model min')
pl.subplot(122)
x = pl.hist(iim3[spte]['model_max'], 40, label='Model Max', color='r', histtype='step')
pl.xlabel('Model max')

# %%
reload(bas)
bas.plot_q(iim3[spte]['model_min'], iim3[spte]['e1'], iim3[spte]['e2'], -0.01, 0, 20, 'Model min', figsize=(8,8))

# %%
reload(bas)
bas.plot_q(iim3[spte]['model_min'], iim3[spte]['e1'], iim3[spte]['e2'], -0.003, 0, 10, 'Model min', figsize=(8,8))

# %%
reload(bas)
bas.plot_q(iim3[spte]['model_max'], iim3[spte]['e1'], iim3[spte]['e2'], 0, 1, 20, 'Model max', figsize=(8,8))

# %%
reload(bas)
bas.plot_q(iim3[spte]['model_max'], iim3[spte]['e1'], iim3[spte]['e2'], 0, 0.1, 10, 'Model max', figsize=(8,8))

# %%
reload(bas)
pl.figure(figsize=(7,7))
x = pl.hist(iim3[spte]['bulge_flux'], 40, range=(-20, 20), label='Bulge flux', color='k', histtype='step')
pl.xlabel('Bulge flux')

# %%
pl.figure(figsize=(7,7))
x = pl.hist(iim3[spte]['disc_flux'], 40, range=(-20, 20), label='Disc flux', color='k', histtype='step')
pl.xlabel('Disc flux')

# %%
pl.figure(figsize=(7,7))
x = pl.hist(iim3[spte]['mean_flux'], 40, range=(0, 10000), label='Mean flux', color='k', histtype='step')
pl.xlabel('Mean flux')

# %%
im3=0
bas.plot_q(iim3[spte]['mean_flux'], iim3[spte]['e1'], iim3[spte]['e2'], 0, 15000, 10, 'Mean flux', figsize=(8,8))

# %%
bas.plot_q(iim3[spte]['mean_flux'], iim3[spte]['e1'], iim3[spte]['e2'], 0, 2000, 50, 'Mean flux', figsize=(8,8))

# %%
bt = iim3[spte]['bulge_flux'] / (abs(iim3[spte]['bulge_flux'])  + abs(iim3[spte]['disc_flux']))

# %%
pl.figure(figsize=(7,7))
x = pl.hist(bt, 40, range=(-2,2), label='B/T', color='k', histtype='step')
pl.xlabel('B/T')

# %% [markdown]
# #### $<e_1> \& <e_2>$ vs B/T

# %%
bas.plot_q(bt, iim3[spte]['e1'], iim3[spte]['e2'], -0.5, 1, 20, 'B/T', figsize=(8,8))

# %% [markdown]
# #### $<e_1> \& <e_2>$ vs abosulte value of B/T

# %%
bas.plot_q(abs(bt), iim3[spte]['e1'], iim3[spte]['e2'], -0., 1, 20, 'B/T', figsize=(8,8))

# %% [markdown]
# #### MEAN_RGPP_RP dependence

# %%
pl.figure(figsize=(7,7))
x = pl.hist(iim3[spte]['MEAN_RGPP_RP'], 40, range=(1,4), label='MEAN_RGPP_RP', color='k', histtype='step')
pl.xlabel('MEAN_RGPP_RP')

# %%
bas.plot_q(iim3[spte]['MEAN_RGPP_RP'], iim3[spte]['e1'], iim3[spte]['e2'], 1, 2., 20, 'MEAN_RGPP_RP', figsize=(8,8))

# %%
iim3[spte]['chi2_pixel'].min()
# Out:
# 0.80001752009722205

# %%
bas.plot_q(iim3[spte]['CHI2_PIXEL'], iim3[spte]['e1'], iim3[spte]['e2'], 0.8, 1.5, 30, 'CHI2_PIXEL', figsize=(8,8))

# %%
bas.plot_q(iim3[spte]['LIKELIHOOD'], iim3[spte]['e1'], iim3[spte]['e2'], -6600, -100., 50, 'LIKELIHOOD', figsize=(8,8))

# %%
pl.figure(figsize=(7,7))
x = pl.hist(iim3[spte]['LIKELIHOOD'], 50, range=(-6600,-100), label='LIKELIHOOD', color='k', histtype='step')
pl.xlabel('LIKELIHOOD')
